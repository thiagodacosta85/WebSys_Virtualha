# %%
# imports
import os
from sqlalchemy import create_engine
import pandas as pd

# %%
# settings
os.system('cls')
os.system('color 6')
# Out:
# 1

# %%
# conector
engine = create_engine(
    "mysql+pymysql://llpdigital:password@192.168.0.163:3306/virtualha")
os.system('cls')

df_localidades = pd.read_sql_query("SELECT * FROM localidades", engine)
df_localidades
# Out:
#     ID_LOCAL                     NOME ZONA  POPULACAO  RESIDENCIAS_CONST  \
# 0          1                   CENTRO    C       5640               1754
# 1          2   COMPLEXO UNIVERSITÁRIO    C          0                  0
# 2          3       COMPLEXO ESPORTIVO    C          0                  0
# 3          4             POLO DIGITAL    C          0                  0
# 4          5                PINHEIROS    C      10966               3157
# 5          6                   BOSQUE    C       1968                554
# 6          7               MADEIREIRA    S        904                266
# 7          8  COMPLEXO ADMINISTRATIVO    C          0                  0
# 8          9         JARDIM ZOOLÓGICO    C          0                  0
# 9         10           UNIVERSITÁRIOS    O       3108                936
# 10        11                  BAIXADA    O       4172               1214
# 11        12                PRIMAVERA    O       1725                504
# 12        13               MATA VERDE    O       1797                514
# 13        14                ZONA RUAL    O          0                  0
# 14        15               PESCADORES    O        356                 99
# 15        16                 HARMONIA    S       2468                693
# 16        17       COMPLEXO SANITÁRIO    S          0                  0
# 17        18                 PLANALTO    S       1586                449
# 18        19                FLORESTAL    S          0                  0
# 19        20       COMPLEXO FABRIL II    S          0                  0
# 20        21         LAGOA DAS PEDRAS    S       2775                787
# 21        22     COMPLEXO FERROVIÁRIO    S          0                  0
# 22        23   COMPLEXO AEROPORTUÁRIO    S          0                  0
# 23        24       COMPLEXO PORTUÁRIO    N          0                  0
# 24        25              PETROLÍFERA    L          0                  0
# 25        26        COMPLEXO FABRIL I    L          0                  0
# 26        27           COMPLEXO NAVAL    L          0                  0
# 27        28        SÍTIO DO CARVALHO    L        579                174
# 28        29            INDUSTRIÁRIOS    L       5715               1642
# 29        30               IMIGRANTES    L       3246                986
# 30        31         CENTRO HISTÓRICO    L       2994                825
# 31        32               MINERADORA    L          0                  0
# 32        33             PRAIA GRANDE    N       4372               1192
# 33        34            CAIS DO FORTE    N          0                  0
# 34        35                HOTELARIA    N         86                 22
# 35        36               MEIA PRAIA    N          0                  0
# 36        37               NAVEGANTES    N       5982               1680
#
#     RESIDENCIAS_POS  TRABALHADORES_EFET  VAGAS_DISP  VIS_TUR  CRIANCAS  \
# 0              1633                2357        2586       72       352
# 1                 0                1944        2627      102         0
# 2                 0                 336         475       43         0
# 3                 0                  76          76       11         0
# 4              3421                2747        2886       55       698
# 5               579                 740         775       35       169
# 6               279                 632         705       15        77
# 7                 0                 677         775       81         0
# 8                 0                  12          16       13         0
# 9               995                 717         735       13       186
# 10             1295                 596         629       19       238
# 11              531                1026        1111       21       149
# 12              531                 595         625       24       131
# 13                0                1224        1473        0         0
# 14              101                 122         123       24        18
# 15              732                 779         853       23       166
# 16                0                 208         219        3         0
# 17              468                 388         432       23       119
# 18                0                 893        1368        0         0
# 19                0                 111         159        0         0
# 20              798                 989        1094       29       180
# 21                0                 232         298       12         0
# 22                0                 321         456        0         0
# 23                0                 378         472       11         0
# 24                0                 882        1366        0         0
# 25                0                 208         207        0         0
# 26                0                 673         955       12         0
# 27              175                  57          57       11        46
# 28             1734                1300        1396       55       410
# 29             1023                2041        2152       50       262
# 30              887                  41          41        7       180
# 31                0                 667        1180        0         0
# 32             1264                1017        1062       38       298
# 33                0                  90          96       27         0
# 34               23                 315         322       41        14
# 35                0                 241         246       12         0
# 36             1802                 527         637       74       431
#
#     ADOLESC  JOVENS_ADUL  ADULTOS  IDOSOS          ATIV  VALOR_MED_TERRENO  \
# 0       862         1167     1472    1787       MORADIA                 70
# 1         0            0        0       0   EDUCACIONAL                 28
# 2         0            0        0       0         LAZER                 27
# 3         0            0        0       0    TECNOLOGIA                 63
# 4      1421         2482     2965    3400       MORADIA                 57
# 5       318          382      576     523       MORADIA                 64
# 6       154          166      257     250       MORADIA                 47
# 7         0            0        0       0     COMERCIAL                 44
# 8         0            0        0       0         LAZER                 48
# 9       370          702      772    1078       MORADIA                 55
# 10      521          990     1084    1339       MORADIA                 54
# 11      301          302      499     474       MORADIA                 50
# 12      260          402      513     491       MORADIA                 49
# 13        0            0        0       0   AGRICULTURA                  0
# 14       45          104       73     116       MORADIA                 26
# 15      353          593      701     655       MORADIA                 42
# 16        0            0        0       0      SERVIÇOS                  2
# 17      277          336      459     359       MORADIA                 40
# 18        0            0        0       0  SILVICULTURA                  0
# 19        0            0        0       0      SERVIÇOS                  0
# 20      423          662      751     759       MORADIA                 33
# 21        0            0        0       0      SERVIÇOS                  9
# 22        0            0        0       0      SERVIÇOS                  1
# 23        0            0        0       0      SERVIÇOS                  6
# 24        0            0        0       0   PETROLÍFERA                  0
# 25        0            0        0       0      SERVIÇOS                  0
# 26        0            0        0       0      SERVIÇOS                  5
# 27       90          109      154     180       MORADIA                 17
# 28      836         1286     1641    1542       MORADIA                 45
# 29      561          532      916     975       MORADIA                 47
# 30      353          859      867     735       MORADIA                 47
# 31        0            0        0       0     MINERAÇÃO                  0
# 32      645         1065     1450     914       MORADIA                 52
# 33        0            0        0       0         LAZER                 37
# 34       10           18       23      21       TURISMO                 52
# 35        0            0        0       0         LAZER                 50
# 36      850         1356     1889    1456       MORADIA                 47
#
#      DATA_FUND
# 0   2022-07-26
# 1   2022-07-26
# 2   2022-07-26
# 3   2022-07-26
# 4   2022-07-26
# 5   2022-07-26
# 6   2022-07-26
# 7   2022-07-26
# 8   2022-07-26
# 9   2022-07-26
# 10  2022-07-26
# 11  2022-07-26
# 12  2022-07-26
# 13  2022-07-26
# 14  2022-07-26
# 15  2022-07-26
# 16  2022-07-26
# 17  2022-07-26
# 18  2022-07-26
# 19  2022-07-26
# 20  2022-07-26
# 21  2022-07-26
# 22  2022-07-26
# 23  2022-07-26
# 24  2022-07-26
# 25  2022-07-26
# 26  2022-07-26
# 27  2022-07-26
# 28  2022-07-26
# 29  2022-07-26
# 30  2022-07-26
# 31  2022-07-26
# 32  2022-07-26
# 33  2022-07-26
# 34  2022-07-26
# 35  2022-07-26
# 36  2022-07-26

# %%
print(type(df_localidades))
#df_localidades.describe()
print(df_localidades.shape)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# (37, 17)
